# %% [markdown]
# # 1.4 Tipos de Datos en Python
#
# ## Introducción
# En esta lección exploraremos los tipos de datos fundamentales en Python...
#
# ## Tipos de Datos Básicos
#
# ### Números Enteros (int)
# ```python
# # Ejemplos de enteros
# edad = 25
# poblacion = 1000000
# print(f"Edad: {edad}, Población: {poblacion}")

# %%
# Ejemplos de flotantes
pi = 3.14159
temperatura = 36.5
print(f"Pi: {pi}, Temperatura: {temperatura}")
